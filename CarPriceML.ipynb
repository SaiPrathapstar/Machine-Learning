# %%
 ##This is a multiple linear regression model

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics  import r2_score
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('CarPrice_Assignment.csv')
cars_numeric = df.select_dtypes(include = ['int64' , 'float64'])
cars_numeric = cars_numeric.drop(columns = ['car_ID' , 'symboling'])
x = cars_numeric.iloc[:,0:13].values
y = cars_numeric.iloc[:,-1].values
x_train , x_test , y_train , y_test = train_test_split(x,y)
model = LinearRegression()
model.fit(x_train , y_train)
y_pred = model.predict(x_test)
r2_score(y_test , y_pred)
df1 = pd.DataFrame({'Actual' : y_test , 'Predicted' : y_pred})
df1.plot(figsize = (15,9))
plt.show()
df1.plot(figsize = (15,9) , kind = 'bar')
sns.distplot(df['price'])
#sns.distplot(df['price'],hist = False)
#sns.distplot(df['price'] , kde = False)

# %%
from sklearn.metrics  import r2_score
r2_score(y_test , y_pred)
# Out:
# 0.8327948187317337

# %%
import matplotlib.pyplot as plt
plt.scatter(y_pred , y_test)
plt.show()
plt.plot(y_pred , y_test)
plt.show()

# %%
import pandas as pd
df1 = pd.DataFrame({'Actual' : y_test , 'Predicted' : y_pred})
df1.plot(figsize = (15,9))
plt.show()
df1.plot(figsize = (15,9) , kind = 'bar')

# %%
import seaborn as sns
sns.distplot(df['price'])

# %%
df1.info()

# %%
df.info()

# %%
df.columns

# %%
df.shape

# %%
df['price'].max()
# Out:
# 45400.0

# %%
df['price'].min()
# Out:
# 5118.0

# %%
cars_numeric

# %%
df.corr()['price'] #Correlation of price column with all other columns

# %%
cars_numeric.columns

# %%
import matplotlib.pyplot as plt
import  pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import seaborn as sns
df = pd.read_csv('CarPrice_Assignment.csv')
cars_numeric = df.select_dtypes(include = ['float64' , 'int64'])
cars_numeric = cars_numeric.drop(columns = ['Car_ID' , 'symboling'])
x = df.iloc[:,0:13]
y = df.iloc[:,-1]
model = LinearRegression()
x_train , x_test , y_train , y_test = train_test_split(x,y)
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
df1 = pd.dataframe({'Actual':y_test,'Predicted':y_pred})
df1.plot(figsize = (15,9))
plt.show()
sns.distplot(df['price'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-90b2f16ab70a> in <module>()
#       7 df = pd.read_csv('CarPrice_Assignment.csv')
#       8 cars_numeric = df.select_dtypes(include = ['float64' , 'int64'])
# ----> 9 cars_numeric = cars_numeric.drop(columns = ['Car_ID' , 'symboling'])
#      10 x = df.iloc[:,0:13]
#      11 y = df.iloc[:,-1]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# ...
